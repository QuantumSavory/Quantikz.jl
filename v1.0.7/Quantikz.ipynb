# %%
using Quantikz

# %% [markdown]
# ## Any array of `QuantikzOp`s is automatically rendered inline

# %%
[
    CNOT(2,1),
    CPHASE(2,3),
    H(4),P(5),
    SWAP(5,6),
    U("Gate",6),
    Measurement(1),
    Measurement("X",2)
]
# Out:
# 8-element Vector{Quantikz.QuantikzOp}:
#  MultiControl(Integer[2], Integer[], Integer[1], Integer[])
#  MultiControl(Integer[2, 3], Integer[], Integer[], Integer[])
#  U("H", 4)
#  U("P", 5)
#  MultiControl(Integer[], Integer[], Integer[], Integer[5, 6])
#  U("Gate", 6)
#  Measurement("", 1)
#  Measurement("X", 2)

# %% [markdown]
# ## `show` or `displaycircuit` also have the `mode` (`:compressed` vs `:expanded`) and `scale` parameters.

# %%
displaycircuit(
    [CNOT(2,1),
     CPHASE(2,3),
     H(4),P(5),
     SWAP(5,6),
     U("Gate",6),
     Measurement(1),
     Measurement("X",2)
    ],
    mode=:expanded
)

# %%
displaycircuit(
    [CNOT(2,1),
     CPHASE(2,3),
     H(4),P(5),
     SWAP(5,6),
     U("Gate",6),
     Measurement(1),
     Measurement("X",2)
    ],
    mode=:compressed, # the default
    scale=2 # default of 1
)

# %% [markdown]
# ## `MultiControl` lets you make unrealistic arbitrary multiqubit ops

# %%
MultiControl([1,8],[2,7],[3,6],[4,5])
# Out:
# MultiControl(Integer[1, 8], Integer[2, 7], Integer[3, 6], Integer[4, 5])

# %% [markdown]
# ## `MultiControlU` lets you make controlled gates with arbitrary names

# %%
[
    MultiControlU("U",[1,2],[3,8],[5,7]),
    MultiControlU("U_a",[1,2],[],[4,5]),
    MultiControlU("U_b",[7,8],[5],[1,2,3]),
    MultiControlU("U_c",[],[],[4,6])
]
# Out:
# 4-element Vector{MultiControlU}:
#  MultiControlU("U", Integer[1, 2], Integer[3, 8], Integer[5, 7])
#  MultiControlU("U_a", Integer[1, 2], Integer[], Integer[4, 5])
#  MultiControlU("U_b", Integer[7, 8], Integer[5], Integer[1, 2, 3])
#  MultiControlU("U_c", Integer[], Integer[], Integer[4, 6])

# %% [markdown]
# ## `Noise` and `NoiseAll` are convenient to denote noise event

# %%
[
    Noise([1,5]),
    P(1),
    NoiseAll(),
    MultiControlU("U",[2],[],[3,4]),
    Noise([2,4]),
]
# Out:
# 5-element Vector{Quantikz.QuantikzOp}:
#  Noise(Integer[1, 5])
#  U("P", 1)
#  NoiseAll()
#  MultiControlU("U", Integer[2], Integer[], Integer[3, 4])
#  Noise(Integer[2, 4])

# %% [markdown]
# ## Use `circuit2table` to inspect the TeX code

# %%
table = circuit2table(
    [CNOT(2,1),
     CPHASE(2,3),
     H(4),P(5),
     SWAP(5,6),
     U("Gate",6),
     Measurement(1),
     Measurement("X",2)
    ],
    mode=:compressed
)
# Out:
# 6×5 Matrix{String}:
#  "\\qw"  "\\targ{}\\vqw{0}"  "\\meterD{}"  ""              ""
#  "\\qw"  "\\ctrl{-1}"        "\\ctrl{0}"   "\\meterD{X}"   ""
#  "\\qw"  "\\qw"              "\\ctrl{-1}"  "\\qw"          "\\qw"
#  "\\qw"  "\\gate{H}"         "\\qw"        "\\qw"          "\\qw"
#  "\\qw"  "\\gate{P}"         "\\swap{0}"   "\\qw"          "\\qw"
#  "\\qw"  "\\qw"              "\\swap{-1}"  "\\gate{Gate}"  "\\qw"

# %%
string = table2string(table)
# Out:
# "\\begin{quantikz}[transparent]\n\\qw & \\targ{}\\vqw{0} & \\meterD{} &  & \\\\\n\\qw & \\ctrl{-1} & \\ctrl{0} & \\meterD{X} & \\\\\n\\qw & \\qw & \\ctrl{-1} & \\qw & \\qw\\\\\n\\qw & \\gate{H} & \\qw & \\qw & \\qw\\\\\n\\qw & \\gate{P} & \\swap{0} & \\qw & \\qw\\\\\n\\qw & \\qw & \\swap{-1} & \\gate{Gate} & \\qw\n\\end{quantikz}"

# %% [markdown]
# ## Use these to save to file

# %%
circuit = [CNOT(2,1), CPHASE(2,3)]
savecircuit(circuit, "file.pdf")
savecircuit(circuit, "file.png")
savetex(circuit, "file.tex")
